# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [raw]
# "players.xlsx’, 'games.xlsx’, 'game_lineups.xlsx’, 'game_events xlsx’, 'appearances.xlsx’

# %%
path = r"C:\Users\Mihir\8_CAPSTONE PROJECT\og_data\\"

# %%
appearances_df = pd.read_excel(path + "appearances.xlsx")

# %% [markdown]
# # appearances_df
# ## -- CONTAINS THE PLAYERS IN GAMES DETAILS LIKE YELLOW/RED CARDS, ASSISTS, GOALS, MINUTES PLAYED (IN EACH GAME)

# %% [markdown]
# ### MISSING VALUE TREATMENT

# %%
appearances_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3568 entries, 0 to 3567
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   appearance_id   3568 non-null   object
#  1   game_id         3568 non-null   int64
#  2   player_id       3568 non-null   int64
#  3   date            3568 non-null   datetime64[ns]
#  4   player_name     3568 non-null   object
#  5   competition_id  3568 non-null   object
#  6   yellow_cards    3568 non-null   int64
#  7   red_cards       3568 non-null   int64
#  8   goals           3568 non-null   int64
#  9   assists         3568 non-null   int64
#  10  minutes_played  3568 non-null   int64
# dtypes: datetime64[ns](1), int64(7), object(3)
# memory usage: 306.8+ KB

# %%
appearances_df.dtypes
# Out:
# appearance_id             object
# game_id                    int64
# player_id                  int64
# date              datetime64[ns]
# player_name               object
# competition_id            object
# yellow_cards               int64
# red_cards                  int64
# goals                      int64
# assists                    int64
# minutes_played             int64
# dtype: object

# %%
appearances_df.head()
# Out:
#     appearance_id  game_id  player_id       date       player_name  \
# 0  2224728_119169  2224728     119169 2012-07-13   Aron Johannsson
# 1  2224732_161244  2224732     161244 2012-07-14     Conor O'Brien
# 2   2224729_39467  2224729      39467 2012-07-15  Clarence Goodson
# 3  2232104_119169  2232104     119169 2012-07-19   Aron Johannsson
# 4   2219794_39475  2219794      39475 2012-07-22    Sacha Kljestan
#
#   competition_id  yellow_cards  red_cards  goals  assists  minutes_played
# 0            DK1             0          0      0        0              90
# 1            DK1             0          0      1        0              90
# 2            DK1             0          0      0        0              90
# 3            ELQ             0          0      0        0              74
# 4           BESC             0          0      0        0               3

# %%
## FUNCTION TO SEGREGATE NUMERICAL AND CATEGORICAL COLUMNS FOR EASY EDA
def data_type(df):
    num = df.select_dtypes(include=["int64", "float64"]).columns.tolist()
    cat = [x for x in df.columns if x not in num]
    return num, cat
    
numerical, categorical = data_type(appearances_df)

print("numerical: ", numerical)
print()
print("categorical: ", categorical)
# Out:
# numerical:  ['game_id', 'player_id', 'yellow_cards', 'red_cards', 'goals', 'assists', 'minutes_played']
#
# categorical:  ['appearance_id', 'date', 'player_name', 'competition_id']

# %%
## GETTING THE DISTRIBUTION FOR EACH NUMERICAL COLUMNS FOR MISSING VALUE IMPUTATION
def distribution(df):
    col = 2
    rows = len(numerical)//col + 1
    fig, ax = plt.subplots(rows, 2, figsize=(20, 10))
    ax = ax.flatten()
    
    for i, column in enumerate(df[numerical].columns):
        sns.histplot(data=df[column], kde=True, ax=ax[i])
        ax[i].set_title(f'Distribution of {column}')
    
    # Adjust layout
    plt.tight_layout()
    plt.show()
distribution(appearances_df)

# %% [raw]
# ## IMPUTE THE CATEGORUICAL MISSING VALUES USING MODE OF THE DATA

# %% [raw]
# def impute_missing_vals(df):
#     for i in df.columns:
#         if i in categorical:
#             mode = df[i].mode()[0]
#             df[i].fillna(mode, inplace = True)
#         elif i in numerical:
#             if i == "height_in_cm":
#                 mean = df[i].mean()
#                 df[i].fillna(mean, inplace = True)
#             else:
#                 median = df[i].median()
#                 df[i].fillna(median, inplace = True)
#
# impute_missing_vals(players_df)

# %%
appearances_df.isnull().sum()
# Out:
# appearance_id     0
# game_id           0
# player_id         0
# date              0
# player_name       0
# competition_id    0
# yellow_cards      0
# red_cards         0
# goals             0
# assists           0
# minutes_played    0
# dtype: int64

# %% [markdown]
# ### OUTLIER TREATMENT

# %%
## COUNTING OUTLIERS IN EACH COLUMNS
def outlier_counts(df, threshold=1.5):
    outlier_count = {}


    for i in df[numerical].columns:
        # Calculate Q1 (25th percentile) and Q3 (75th percentile)
        q1 = df[i].quantile(0.25)
        q3 = df[i].quantile(0.75)

        # Calculate Interquartile Range (IQR)
        iqr = q3 - q1

        # Calculate lower and upper fences
        lf = q1 - (iqr * threshold)
        uf = q3 + (iqr * threshold)

        # Initialize the outlier count for this column
        outlier_count[i] = 0
        
        # Count the number of values below the lower fence and above the upper fence
        lower_outliers = (df[i] < lf).sum()
        upper_outliers = (df[i] > uf).sum()

        # Total outliers is the sum of lower and upper outliers
        outlier_count[i] = lower_outliers + upper_outliers

    return outlier_count
    
outlier_count = outlier_counts(appearances_df)

outlier_count
# Out:
# {'game_id': 0,
#  'player_id': 3,
#  'yellow_cards': 440,
#  'red_cards': 12,
#  'goals': 298,
#  'assists': 252,
#  'minutes_played': 0}

# %% [raw]
# ## TREATING OUTLIERS IN EACH COLUMN
# def winsorization(df, threshold = 1.5):
#     winsorized_df = df.copy()
#     for i in winsorized_df[numerical].columns:
#         q1 = winsorized_df[i].quantile(0.25)
#         q3 = winsorized_df[i].quantile(0.75)
#
#         iqr = q3 - q1
#
#         lf = q1 - (iqr * threshold)
#         uf = q3 + (iqr * threshold)
#
#
#         if winsorized_df[i].dtype == "float64":
#             winsorized_df.loc[winsorized_df[i] < lf, i] = lf
#             winsorized_df.loc[winsorized_df[i] > uf, i] = uf
#         elif winsorized_df[i].dtype == "int64":
#             winsorized_df.loc[winsorized_df[i] < lf, i] = int(lf)
#             winsorized_df.loc[winsorized_df[i] > uf, i] = int(uf)
#     return winsorized_df
# appearances_df_winsorised = winsorization(appearances_df)
#
# #players_df_winsorised

# %%
## CHECKING FOR VALID OUTLIER TREATMENT
outlier_count = outlier_counts(appearances_df)
outlier_count
# Out:
# {'game_id': 0,
#  'player_id': 3,
#  'yellow_cards': 440,
#  'red_cards': 12,
#  'goals': 298,
#  'assists': 252,
#  'minutes_played': 0}

# %% [markdown]
# ### DATATYPE CONVERSION

# %%
# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
appearances_df.head()
# Out:
#     appearance_id  game_id  player_id       date       player_name  \
# 0  2224728_119169  2224728     119169 2012-07-13   Aron Johannsson
# 1  2224732_161244  2224732     161244 2012-07-14     Conor O'Brien
# 2   2224729_39467  2224729      39467 2012-07-15  Clarence Goodson
# 3  2232104_119169  2232104     119169 2012-07-19   Aron Johannsson
# 4   2219794_39475  2219794      39475 2012-07-22    Sacha Kljestan
#
#   competition_id  yellow_cards  red_cards  goals  assists  minutes_played
# 0            DK1             0          0      0        0              90
# 1            DK1             0          0      1        0              90
# 2            DK1             0          0      0        0              90
# 3            ELQ             0          0      0        0              74
# 4           BESC             0          0      0        0               3

# %%
for i in appearances_df.columns:
    print(f"{i}-->{appearances_df[i].unique()}")
    print()
# Out:
# appearance_id-->['2224728_119169' '2224732_161244' '2224729_39467' ... '3431983_478940'
#  '3450575_361104' '3412904_124732']
#
# game_id-->[2224728 2224732 2224729 ... 3431983 3450575 3412904]
#
# player_id-->[119169 161244  39467  39475  46472  39897   1335  39378   3476  49723
#   73427   4267  31041  61575   1321  31642  30593  38383  39471  27577
#   50987  12517 104203  71107 116791 140069 124732 111783 103952 161204
#  175996 228370 131171 160670 209019 355369 273570  94167 255916  58500
#  315779 265671 184133 131183 245893   4746 176850 307781  72519 223047
#  341049 103064 141704 332697 242284 368898 381187 229912 336168 190269
#  542776 334992 451860 258888 370846 282199  77714 483047 411302 336160
#  448696 145466 544931 393325 332705 605498  24637 354613 361104 465104
#  221624 354609 367423 511815 469860 504215 578539 482493 125698 537467
#  315762 478940]
#
# date--><DatetimeArray>
# ['2012-07-13 00:00:00', '2012-07-14 00:00:00', '2012-07-15 00:00:00',
#  '2012-07-19 00:00:00', '2012-07-22 00:00:00', '2012-07-23 00:00:00',
#  '2012-07-26 00:00:00', '2012-07-28 00:00:00', '2012-07-29 00:00:00',
#  '2012-07-30 00:00:00',
#  ...
#  '2020-09-13 00:00:00', '2020-09-14 00:00:00', '2020-09-18 00:00:00',
#  '2020-09-19 00:00:00', '2020-09-20 00:00:00', '2020-09-21 00:00:00',
#  '2020-09-24 00:00:00', '2020-09-25 00:00:00', '2020-09-26 00:00:00',
#  '2020-09-27 00:00:00']
# Length: 1267, dtype: datetime64[ns]
#
# player_name-->['Aron Johannsson' "Conor O'Brien" 'Clarence Goodson' 'Sacha Kljestan'
#  'Charlie Davies' 'Michael Parkhurst' 'Steven Cherundolo' 'Jozy Altidore'
#  'Brad Friedel' 'Timothy Chandler' 'Caleb Patterson-Sewell' 'Tim Howard'
#  'Fabian Johnson' 'Eric Lichaj' 'Jermaine Jones' 'Geoff Cameron'
#  'Michael Bradley' 'Danny Williams' 'Brad Guzan' 'Clint Dempsey'
#  'Maurice Edu' 'Oguchi Onyewu' 'Eugene Starikov' 'Brek Shea' 'Don Cowan'
#  'Babajide Ogunbiyi' 'John Anthony Brooks' 'Alejandro Bedoya'
#  'Mike Grella' 'Julian Green' 'Sebastian Lletget' 'Gedion Zelalem'
#  'Juan Agudelo' 'Joe Gyau' 'Kenny Saief' 'Jordan' 'Desevio Payne'
#  'Jerome Kiesewetter' 'DeAndre Yedlin' 'Alfredo Morales'
#  'Christian Pulisic' 'George Fochive' 'Russell Canouse' 'Perry Kitchen'
#  'Matt Miazga' 'David Yelldell' 'A.J. Soares' 'Lynden Gooch' 'Bobby Wood'
#  'Emerson Hyndman' 'Cameron Carter-Vickers' 'Terrence Boyd' 'Steve Clark'
#  'Weston McKennie' 'Ethan Horvath' 'Juan Torres' 'Emmanuel Sabbi'
#  "Shane O'Neill" 'Shaq Moore' 'Caleb Stanko' 'Jonathan Amon'
#  'Jonathan Klinsmann' 'Keaton Parks' 'Kyle Scott' 'Timothy Weah'
#  'Erik Palmer-Brown' 'Bill Hamid' 'Seyi Adekoya' 'Brendan Hines-Ike'
#  'Andrija Novakovich' 'Michael Lansing' 'Tim Ream' 'Christian Cappis'
#  'Josh Sargent' 'Tyler Adams' 'Sebastian Soto' 'Jonathan Spector'
#  'Matt Polster' 'Sergino Dest' 'Yosef Samuel' 'Zack Steffen'
#  'Khiry Shelton' 'Chris Durkin' 'Owen Otasowie' 'Indiana Vassilev'
#  'Giovanni Reyna' 'Chris Richards' 'Ian Harkes' 'Dillon Powers'
#  'Joseph Efford' 'Luca de la Torre' 'Reggie Cannon']
#
# competition_id-->['DK1' 'ELQ' 'BESC' 'CLQ' 'BE1' 'NL1' 'GB1' 'DFB' 'PO1' 'L1' 'IT1' 'CL'
#  'EL' 'DKP' 'NLP' 'CDR' 'ES1' 'RU1' 'CIT' 'POCP' 'FAC' 'TR1' 'SC1' 'NLSC'
#  'FR1' 'UKR1' 'UKRP' 'SFA' 'DFL' 'FRCH' 'USC']
#
# yellow_cards-->[0 1 2]
#
# red_cards-->[0 1]
#
# goals-->[0 1 2 4 3]
#
# assists-->[0 1 2]
#
# minutes_played-->[ 90  74   3  21  73  43  56  19  78  28   9  45  85  66  24  84  20  18
#   62 120  71   1  31  81  68  60  70  52   6  12  76  82   2  88  69  67
#   65  10  17  11  63  15  36  72  77   8  32  87  29  79  39  83  37  58
#   80  38  59  64  54   5  47  75  22  51  27  13  26  14  30  16  35  33
#   23  86  89  57  61  25   7  34   4  49  55  40 101  46  42  48  53  50]

# %%
appearances_df.to_csv("appearances_df_no_win.csv", index = False)
