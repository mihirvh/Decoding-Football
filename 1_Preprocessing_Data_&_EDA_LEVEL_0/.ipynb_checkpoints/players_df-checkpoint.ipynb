# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [raw]
# "players.xlsx’, 'games.xlsx’, 'game_lineups.xlsx’, 'game_events xlsx’, 'appearances.xlsx’

# %%
path = r"C:\Users\Mihir\8_CAPSTONE PROJECT\og_data\\"

# %%
players_df = pd.read_excel(path + "players.xlsx")
appearances_df = pd.read_excel(path + "appearances.xlsx")
games_df = pd.read_excel(path + "games.xlsx")
game_lineups_df = pd.read_excel(path + "game_lineups.xlsx")
game_events_df = pd.read_excel(path + "game_events.xlsx")
test_df = pd.read_excel(path + "test data.xlsx")

# %% [markdown]
# # players_df
# ## -- CONTAINS PLAYER DETAILS LIKE NAME, COUNTRY, HEIGHT, CLUB, POSITION/SUBPOSITION, MARKETVALUE, CONTRACT DATE AND AGENT ASSOCIATED

# %% [markdown]
# ### MISSING VALUE TREATMENT

# %%
players_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   player_id                    152 non-null    int64
#  1   name                         152 non-null    object
#  2   last_season                  152 non-null    int64
#  3   current_club_id              152 non-null    int64
#  4   player_code                  152 non-null    object
#  5   country_of_birth             152 non-null    object
#  6   date_of_birth                152 non-null    datetime64[ns]
#  7   sub_position                 152 non-null    object
#  8   position                     152 non-null    object
#  9   foot                         141 non-null    object
#  10  height_in_cm                 149 non-null    float64
#  11  market_value_in_eur          114 non-null    float64
#  12  highest_market_value_in_eur  148 non-null    float64
#  13  contract_expiration_date     106 non-null    datetime64[ns]
#  14  agent_name                   107 non-null    object
# dtypes: datetime64[ns](2), float64(3), int64(3), object(7)
# memory usage: 17.9+ KB

# %%
players_df.dtypes
# Out:
# player_id                               int64
# name                                   object
# last_season                             int64
# current_club_id                         int64
# player_code                            object
# country_of_birth                       object
# date_of_birth                  datetime64[ns]
# sub_position                           object
# position                               object
# foot                                   object
# height_in_cm                          float64
# market_value_in_eur                   float64
# highest_market_value_in_eur           float64
# contract_expiration_date       datetime64[ns]
# agent_name                             object
# dtype: object

# %%
## FUNCTION TO SEGREGATE NUMERICAL AND CATEGORICAL COLUMNS FOR EASY EDA
def data_type(df):
    num = df.select_dtypes(include=["int64", "float64"]).columns.tolist()
    cat = [x for x in df.columns if x not in num]
    return num, cat
    
numerical, categorical = data_type(players_df)

print("numerical: ", numerical)
print()
print("categorical: ", categorical)
# Out:
# numerical:  ['player_id', 'last_season', 'current_club_id', 'height_in_cm', 'market_value_in_eur', 'highest_market_value_in_eur']
#
# categorical:  ['name', 'player_code', 'country_of_birth', 'date_of_birth', 'sub_position', 'position', 'foot', 'contract_expiration_date', 'agent_name']

# %%
## GETTING THE DISTRIBUTION FOR EACH NUMERICAL COLUMNS FOR MISSING VALUE IMPUTATION
def distribution(df):
    col = 2
    rows = len(numerical)//col
    fig, ax = plt.subplots(rows, 2, figsize=(20, 15))
    ax = ax.flatten()
    
    for i, column in enumerate(df[numerical].columns):
        sns.histplot(data=df[column], kde=True, ax=ax[i])
        ax[i].set_title(f'Distribution of {column}')
    
    # Adjust layout
    plt.tight_layout()
    plt.show()
distribution(players_df)

# %% [raw]
# sns.histplot(data=players_df["market_value_in_eur"], kde=True)
# #ax[i].set_title(f'Distribution of {column}')

# %%
players_df[numerical].isnull().sum()
# Out:
# player_id                       0
# last_season                     0
# current_club_id                 0
# height_in_cm                    3
# market_value_in_eur            38
# highest_market_value_in_eur     4
# dtype: int64

# %% [raw]
# ## EXCEPT HEIGHT HAVING NORMAL DISTRIBUTION ALL THE OTHER NUMERICAL COLUMNS HAVE SKEWED DISTRUIBUTION
# ## HEIGHT -- MEAN
# ## market_value_in_eur -- MEDIAN
# ##highest_market_value_in_eur -- MEDIAN

# %%
players_df[categorical].isnull().sum()
# Out:
# name                         0
# player_code                  0
# country_of_birth             0
# date_of_birth                0
# sub_position                 0
# position                     0
# foot                        11
# contract_expiration_date    46
# agent_name                  45
# dtype: int64

# %% [raw]
# ## IMPUTE THE CATEGORUICAL MISSING VALUES USING MODE OF THE DATA

# %%
def impute_missing_vals(df):
    for i in df.columns:
        if i in categorical:
            mode = df[i].mode()[0]
            df[i].fillna(mode, inplace = True)
        elif i in numerical:
            if i == "height_in_cm":
                mean = df[i].mean()
                df[i].fillna(mean, inplace = True)
            else:
                median = df[i].median()
                df[i].fillna(median, inplace = True)
                
impute_missing_vals(players_df)

# %%
players_df.isnull().sum()
# Out:
# player_id                      0
# name                           0
# last_season                    0
# current_club_id                0
# player_code                    0
# country_of_birth               0
# date_of_birth                  0
# sub_position                   0
# position                       0
# foot                           0
# height_in_cm                   0
# market_value_in_eur            0
# highest_market_value_in_eur    0
# contract_expiration_date       0
# agent_name                     0
# dtype: int64

# %% [markdown]
# ### OUTLIER TREATMENT

# %%
## COUNTING OUTLIERS IN EACH COLUMNS
def outlier_counts(df, threshold=1.5):
    outlier_count = {}


    for i in df[numerical].columns:
        # Calculate Q1 (25th percentile) and Q3 (75th percentile)
        q1 = df[i].quantile(0.25)
        q3 = df[i].quantile(0.75)

        # Calculate Interquartile Range (IQR)
        iqr = q3 - q1

        # Calculate lower and upper fences
        lf = q1 - (iqr * threshold)
        uf = q3 + (iqr * threshold)

        # Initialize the outlier count for this column
        outlier_count[i] = 0
        
        # Count the number of values below the lower fence and above the upper fence
        lower_outliers = (df[i] < lf).sum()
        upper_outliers = (df[i] > uf).sum()

        # Total outliers is the sum of lower and upper outliers
        outlier_count[i] = lower_outliers + upper_outliers

    return outlier_count
    
outlier_count = outlier_counts(players_df)

outlier_count
# Out:
# {'player_id': 1,
#  'last_season': 0,
#  'current_club_id': 19,
#  'height_in_cm': 2,
#  'market_value_in_eur': 26,
#  'highest_market_value_in_eur': 16}

# %%
## TREATING OUTLIERS IN EACH COLUMN 
def winsorization(df, threshold = 1.5):
    winsorized_df = df.copy()
    for i in winsorized_df[['height_in_cm', 'market_value_in_eur','highest_market_value_in_eur']].columns:
        q1 = winsorized_df[i].quantile(0.25)
        q3 = winsorized_df[i].quantile(0.75)
        
        iqr = q3 - q1

        lf = q1 - (iqr * threshold)
        uf = q3 + (iqr * threshold)
        

        if winsorized_df[i].dtype == "float64":
            winsorized_df.loc[winsorized_df[i] < lf, i] = lf
            winsorized_df.loc[winsorized_df[i] > uf, i] = uf
        elif winsorized_df[i].dtype == "int64":
            winsorized_df.loc[winsorized_df[i] < lf, i] = int(lf)
            winsorized_df.loc[winsorized_df[i] > uf, i] = int(uf)
    return winsorized_df   
players_df_winsorised = winsorization(players_df)

#players_df_winsorised

# %%
## CHECKING FOR VALID OUTLIER TREATMENT
outlier_count = outlier_counts(players_df_winsorised)
outlier_count
# Out:
# {'player_id': 1,
#  'last_season': 0,
#  'current_club_id': 19,
#  'height_in_cm': 0,
#  'market_value_in_eur': 0,
#  'highest_market_value_in_eur': 0}

# %% [markdown]
# ### DATATYPE CONVERSION

# %%
# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
players_df_winsorised.head()
# Out:
#    player_id                 name  last_season  current_club_id  \
# 0     124732  John Anthony Brooks         2023              533
# 1     223047      Emerson Hyndman         2018              903
# 2     307781         Lynden Gooch         2016              289
# 3     370846         Timothy Weah         2023              506
# 4     484756   Djordje Mihailovic         2023             1090
#
#            player_code country_of_birth date_of_birth        sub_position  \
# 0  john-anthony-brooks          Germany    1993-01-28         Centre-Back
# 1      emerson-hyndman    United States    1996-04-09    Central Midfield
# 2         lynden-gooch    United States    1995-12-24        Right Winger
# 3         timothy-weah    United States    2000-02-22      Right Midfield
# 4   djordje-mihailovic    United States    1998-11-10  Attacking Midfield
#
#    position   foot  height_in_cm  market_value_in_eur  \
# 0  Defender   left         194.0            2000000.0
# 1  Midfield  right         170.0             800000.0
# 2    Attack  right         173.0            1000000.0
# 3  Midfield  right         183.0            4137500.0
# 4  Midfield  right         178.0            4137500.0
#
#    highest_market_value_in_eur contract_expiration_date           agent_name
# 0                   11468750.0               2024-06-30                ROGON
# 1                    1800000.0               2025-06-30           OmniSports
# 2                    1000000.0               2024-06-30  Unique Sports Group
# 3                   11468750.0               2028-06-30    BS Group - BS Law
# 4                    6000000.0               2026-06-30  YMU Management Ltd.

# %%
for i in players_df_winsorised.columns:
    print(f"{i}-->{players_df_winsorised[i].unique()}")
    print()
# Out:
# player_id-->[ 124732  223047  307781  370846  484756  659781 1163778   72519  104203
#   125698  408562  425306  482493  605498  696762   30593   49723   59471
#    31041  184133  229912  255916  334992  351503  370844  389253  448696
#   562387  747967  795738   24637   39471  131171  271107  119169  161204
#   228370  258888  627183  627198  678194   39475   77714  175996  176850
#   315779  393323  692736  245893  411302  478940  483047  544931  704156
#   742297   12517   31642  170540  209019  392710  971613  367423  381187
#   526111  627205  656316  699461  746838  763798  131183  236590    1335
#   469858  504209  860812   58500   71107  141704  221624  315762  336168
#   349701  368898    1321    4267   27577   38383  103064  242284  332705
#   575367  627207  475208  504147  513963  535282  190269  336160  354613
#   393321  429259  465104  670144  711517   50987  341049  346644  469860
#   542776    4746  354609  504153  796429   39897   73427  116791  161244
#   332697  503770  646122  674501   39467   46472   61575  447216  503991
#   393325  511815  145466  265671  282199  349699  466809  537467  605144
#   623872   39378  355369  361104  467437   94167  103559  103952  140069
#   451860  578539  670096  273570  111783  160670    3476  504215]
#
# name-->['John Anthony Brooks' 'Emerson Hyndman' 'Lynden Gooch' 'Timothy Weah'
#  'Djordje Mihailovic' 'Jack de Vries' 'Kahveh Zahiroleslam' 'Bobby Wood'
#  'Eugene Starikov' 'Dillon Powers' 'Marlon Fossey' 'Matt Turner'
#  'Ian Harkes' 'Sebastian Soto' 'Jonathan Tomkinson' 'Michael Bradley'
#  'Timothy Chandler' 'Chris Konopka' 'Fabian Johnson' 'Russell Canouse'
#  "Shane O'Neill" 'DeAndre Yedlin' 'Jonathan Klinsmann' 'Kevin Silva'
#  'Brady Scott' 'Auston Trusty' 'Michael Lansing' 'Chris Mueller'
#  'Brian Schwake' 'Paxten Aaronson' 'Jonathan Spector' 'Brad Guzan'
#  'Juan Agudelo' 'Travis Brent' 'Aron Johannsson' 'Julian Green'
#  'Gedion Zelalem' 'Kyle Scott' 'Benji Michel' 'Chituru Odunze'
#  'Matthew Hoppe' 'Sacha Kljestan' 'Bill Hamid' 'Sebastian Lletget'
#  'A.J. Soares' 'Christian Pulisic' 'Brenden Aaronson' 'Malick Sanogo'
#  'Matt Miazga' 'Brendan Hines-Ike' 'Reggie Cannon' 'Seyi Adekoya'
#  'Christian Cappis' 'Nicholas Gioacchini' 'Caden Clark' 'Oguchi Onyewu'
#  'Geoff Cameron' 'Cody Cropper' 'Kenny Saief' 'Lennard Maloney'
#  'Dante Polvara' 'Chris Durkin' 'Emmanuel Sabbi' 'Alex Mendez'
#  'Griffin Yow' 'Gabriel Slonina' 'Cameron Harper' 'Zach Booth'
#  'Alejandro Alvarado' 'Perry Kitchen' 'Christian Ramirez'
#  'Steven Cherundolo' 'Ulysses Llanez' 'Gianluca Busio' 'Agustin Anello'
#  'Alfredo Morales' 'Brek Shea' 'Steve Clark' 'Zack Steffen'
#  'Luca de la Torre' 'Shaq Moore' 'Antonee Robinson' 'Juan Torres'
#  'Jermaine Jones' 'Tim Howard' 'Clint Dempsey' 'Danny Williams'
#  'Terrence Boyd' 'Ethan Horvath' 'Tyler Adams' 'Richard Ledezma'
#  'Ricardo Pepi' 'Bryan Reynolds' 'George Bello' 'Taylor Booth' 'Sam Vines'
#  'Caleb Stanko' 'Andrija Novakovich' 'Matt Polster' 'James Sands'
#  'Mark McKenzie' 'Yosef Samuel' 'Jose Gallegos' 'Kevin Paredes'
#  'Maurice Edu' 'Cameron Carter-Vickers' 'Joel Sonora' 'Indiana Vassilev'
#  'Jonathan Amon' 'David Yelldell' 'Khiry Shelton' 'Joe Scally'
#  'Justin Che' 'Michael Parkhurst' 'Caleb Patterson-Sewell' 'Don Cowan'
#  "Conor O'Brien" 'Weston McKennie' 'Folarin Balogun' 'Jacob Samnik'
#  'Jonathan Gomez' 'Clarence Goodson' 'Charlie Davies' 'Eric Lichaj'
#  'Anthony Fontana' 'Yunus Musah' 'Josh Sargent' 'Owen Otasowie' 'Tim Ream'
#  'George Fochive' 'Erik Palmer-Brown' 'Kyle Duncan' 'Konrad de la Fuente'
#  'Joseph Efford' 'Cole Bassett' 'Patrick Leal' 'Jozy Altidore' 'Jordan'
#  'Sergino Dest' 'Malik Tillman' 'Jerome Kiesewetter' 'Mix Diskerud'
#  'Mike Grella' 'Babajide Ogunbiyi' 'Keaton Parks' 'Chris Richards'
#  'Tanner Tessmann' 'Desevio Payne' 'Alejandro Bedoya' 'Joe Gyau'
#  'Brad Friedel' 'Giovanni Reyna']
#
# last_season-->[2023 2018 2016 2021 2015 2020 2022 2013 2019 2017 2014 2012]
#
# current_club_id-->[  533   903   289   506  1090   607   475    42  6992  1519  3057   703
#   1123    12    24  2759    18   798   141    44    43     3   350  2414
#   1241   641   512  1304    86    65    11   631  8024  1003    58   865
#    379   678     5    89  1108   601  2503 19657   206   969 23826  1084
#    180  2036   370   738  6912   968  1245   371   724  5724    82   468
#     38   281   940  3368   931   498   114    29  1110   105   989   383
#     10   200  1096  3999   385   124  1184  5818  5817    20  1301   405
#    369    15   127   167  2424   511   162   681  6646  1269  2282  1063
#    265  2861   683  2671    79   833   294   873  1283   995    16   148]
#
# player_code-->['john-anthony-brooks' 'emerson-hyndman' 'lynden-gooch' 'timothy-weah'
#  'djordje-mihailovic' 'jack-de-vries' 'kahveh-zahiroleslam' 'bobby-wood'
#  'eugene-starikov' 'dillon-powers' 'marlon-fossey' 'matt-turner'
#  'ian-harkes' 'sebastian-soto' 'jonathan-tomkinson' 'michael-bradley'
#  'timothy-chandler' 'chris-konopka' 'fabian-johnson' 'russell-canouse'
#  'shane-oneill' 'deandre-yedlin' 'jonathan-klinsmann' 'kevin-silva'
#  'brady-scott' 'auston-trusty' 'michael-lansing' 'chris-mueller'
#  'brian-schwake' 'paxten-aaronson' 'jonathan-spector' 'brad-guzan'
#  'juan-agudelo' 'travis-brent' 'aron-johannsson' 'julian-green'
#  'gedion-zelalem' 'kyle-scott' 'benji-michel' 'chituru-odunze'
#  'matthew-hoppe' 'sacha-kljestan' 'bill-hamid' 'sebastian-lletget'
#  'a-j-soares' 'christian-pulisic' 'brenden-aaronson' 'malick-sanogo'
#  'matt-miazga' 'brendan-hines-ike' 'reggie-cannon' 'seyi-adekoya'
#  'christian-cappis' 'nicholas-gioacchini' 'caden-clark' 'oguchi-onyewu'
#  'geoff-cameron' 'cody-cropper' 'kenny-saief' 'lennard-maloney'
#  'dante-polvara' 'chris-durkin' 'emmanuel-sabbi' 'alex-mendez'
#  'griffin-yow' 'gabriel-slonina' 'cameron-harper' 'zach-booth'
#  'alejandro-alvarado' 'perry-kitchen' 'christian-ramirez'
#  'steven-cherundolo' 'ulysses-llanez' 'gianluca-busio' 'agustin-anello'
#  'alfredo-morales' 'brek-shea' 'steve-clark' 'zack-steffen'
#  'luca-de-la-torre' 'shaq-moore' 'antonee-robinson' 'juan-torres'
#  'jermaine-jones' 'tim-howard' 'clint-dempsey' 'danny-williams'
#  'terrence-boyd' 'ethan-horvath' 'tyler-adams' 'richard-ledezma'
#  'ricardo-pepi' 'bryan-reynolds' 'george-bello' 'taylor-booth' 'sam-vines'
#  'caleb-stanko' 'andrija-novakovich' 'matt-polster' 'james-sands'
#  'mark-mckenzie' 'yosef-samuel' 'jose-gallegos' 'kevin-paredes'
#  'maurice-edu' 'cameron-carter-vickers' 'joel-sonora' 'indiana-vassilev'
#  'jonathan-amon' 'david-yelldell' 'khiry-shelton' 'joe-scally'
#  'justin-che' 'michael-parkhurst' 'caleb-patterson-sewell' 'don-cowan'
#  'conor-obrien' 'weston-mckennie' 'folarin-balogun' 'jacob-samnik'
#  'jonathan-gomez' 'clarence-goodson' 'charlie-davies' 'eric-lichaj'
#  'anthony-fontana' 'yunus-musah' 'josh-sargent' 'owen-otasowie' 'tim-ream'
#  'george-fochive' 'erik-palmer-brown' 'kyle-duncan' 'konrad-de-la-fuente'
#  'joseph-efford' 'cole-bassett' 'patrick-leal' 'jozy-altidore' 'jordan'
#  'sergino-dest' 'malik-tillman' 'jerome-kiesewetter' 'mix-diskerud'
#  'mike-grella' 'babajide-ogunbiyi' 'keaton-parks' 'chris-richards'
#  'tanner-tessmann' 'desevio-payne' 'alejandro-bedoya' 'joe-gyau'
#  'brad-friedel' 'giovanni-reyna']
#
# country_of_birth-->['Germany' 'United States' 'UdSSR' 'England' 'Ireland' 'Colombia' 'Italy'
#  'Nigeria' 'Ethiopia' 'Netherlands' 'Norway']
#
# date_of_birth--><DatetimeArray>
# ['1993-01-28 00:00:00', '1996-04-09 00:00:00', '1995-12-24 00:00:00',
#  '2000-02-22 00:00:00', '1998-11-10 00:00:00', '2002-03-28 00:00:00',
#  '2002-06-13 00:00:00', '1992-11-15 00:00:00', '1988-11-17 00:00:00',
#  '1991-02-14 00:00:00',
#  ...
#  '1987-01-23 00:00:00', '1986-11-30 00:00:00', '1997-08-06 00:00:00',
#  '2000-03-28 00:00:00', '2001-09-24 00:00:00', '1995-11-30 00:00:00',
#  '1987-04-29 00:00:00', '1992-09-16 00:00:00', '1971-05-18 00:00:00',
#  '2002-11-13 00:00:00']
# Length: 147, dtype: datetime64[ns]
#
# sub_position-->['Centre-Back' 'Central Midfield' 'Right Winger' 'Right Midfield'
#  'Attacking Midfield' 'Centre-Forward' 'Defensive Midfield' 'Right-Back'
#  'Goalkeeper' 'Left Winger' 'Left Midfield' 'Left-Back' 'Second Striker']
#
# position-->['Defender' 'Midfield' 'Attack' 'Goalkeeper']
#
# foot-->['left' 'right' 'both']
#
# height_in_cm-->[194.         170.         173.         183.         178.
#  193.         180.         175.         179.         191.
#  190.         189.         186.         197.         177.
#  188.         181.         187.         185.         176.
#  184.         172.         200.         182.         182.76510067
#  162.375      195.         174.         192.         203.375
#  171.        ]
#
# market_value_in_eur-->[2000000.  800000. 1000000. 4137500.  250000.  400000.  200000. 2500000.
#   450000.  350000.  150000.  700000.  500000.  125000.  100000. 4000000.
#  1200000.  600000.  300000. 3500000. 3000000. 1500000.  750000.  850000.
#  1800000.  900000.  650000.   75000.]
#
# highest_market_value_in_eur-->[11468750.  1800000.  1000000.  6000000.   250000.  2000000.  4500000.
#    500000.   950000.  2500000. 10000000.   700000.   550000.   150000.
#   6500000.  5000000.  7000000.  8000000.   300000.   100000.   125000.
#    400000.  3500000.  4000000.  1500000.  3000000.   900000.   800000.
#    650000.  1200000.  9000000.   600000.  1300000.   350000.  2800000.
#   1750000.   850000.  1700000.  1600000.    50000.   750000.  1850000.
#   2200000.    75000.  1400000.]
#
# contract_expiration_date--><DatetimeArray>
# ['2024-06-30 00:00:00', '2025-06-30 00:00:00', '2028-06-30 00:00:00',
#  '2026-06-30 00:00:00', '2023-06-30 00:00:00', '2023-12-31 00:00:00',
#  '2023-11-30 00:00:00', '2027-06-30 00:00:00', '2023-05-31 00:00:00',
#  '2024-12-31 00:00:00', '2025-12-31 00:00:00', '2026-12-31 00:00:00',
#  '2026-05-31 00:00:00', '2027-12-31 00:00:00', '2024-05-31 00:00:00']
# Length: 15, dtype: datetime64[ns]
#
# agent_name-->['ROGON' 'OmniSports' 'Unique Sports Group' 'BS Group - BS Law'
#  'YMU Management Ltd.' 'CAA Stellar' 'Wasserman' 'PRO FC' 'Prosport'
#  'New Vision' 'CCC' 'Football Company Srl' 'Robert Schneider'
#  'AKA Global GmbH' 'Mega Sports' 'Octagon' 'Sports Invest UK ltd'
#  'SK Soccer Tours' 'YMU Group' 'acta7' 'athleteMNGment' 'Bond MG'
#  'CAA Base Ltd' 'PROSPORT Management' 'CN Sports' 'Promoesport'
#  'in4 sports' 'CMG Sports' 'Avid Sports Group' 'SXI' 'Beswicks Sports Ltd'
#  'ARP Sportmarketing' 'More than Sport GmbH' 'FGM' 'Field Management'
#  'FC Enterprise' 'TrueSports GmbH' 'SBM' 'Shot Sports' 'INSUA GROUP'
#  'GROW' 'fair-sport GmbH' 'PG 120 Sport Agency' 'CT10 management Srl'
#  'NVA SEG' 'InterStarDeporte' 'TOP Agency' 'Gestifute' 'Joes Blakborn'
#  'ROOF' 'BR Group Management']

# %%
players_df_winsorised["country_of_birth"] = players_df_winsorised["country_of_birth"].astype('category')
players_df_winsorised["sub_position"] = players_df_winsorised["sub_position"].astype('category')
players_df_winsorised["position"] = players_df_winsorised["position"].astype('category')
players_df_winsorised["foot"] = players_df_winsorised["foot"].astype('category')
players_df_winsorised["last_season"] = players_df_winsorised["last_season"].astype('category')

# %%
players_df_winsorised.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   player_id                    152 non-null    int64
#  1   name                         152 non-null    object
#  2   last_season                  152 non-null    category
#  3   current_club_id              152 non-null    int64
#  4   player_code                  152 non-null    object
#  5   country_of_birth             152 non-null    category
#  6   date_of_birth                152 non-null    datetime64[ns]
#  7   sub_position                 152 non-null    category
#  8   position                     152 non-null    category
#  9   foot                         152 non-null    category
#  10  height_in_cm                 152 non-null    float64
#  11  market_value_in_eur          152 non-null    float64
#  12  highest_market_value_in_eur  152 non-null    float64
#  13  contract_expiration_date     152 non-null    datetime64[ns]
#  14  agent_name                   152 non-null    object
# dtypes: category(5), datetime64[ns](2), float64(3), int64(2), object(3)
# memory usage: 14.5+ KB

# %%
players_df_winsorised.to_csv("players_df_winsorised.csv", index = False)
